# %% [markdown]
# # Business Objective
#
# Objective
#
# The objective of this notebook is to deploy the trained customer churn prediction model as an interactive web application using Streamlit. Unlike the previous notebooks, which focused on data preparation, model development, evaluation, and business analysis, this notebook demonstrates how the final machine learning model can be transformed into a practical decision-support tool.
#
# The deployed application enables users to enter customer information through a graphical interface, predict the likelihood of customer churn in real time, and receive actionable business recommendations based on the predicted risk.

# %% [markdown]
# # Deployment Workflow
#
# Customer Information
#         │
#         ▼
# Interactive Streamlit Form
#         │
#         ▼
# Generate Engineered Features
#         │
#         ▼
# Load Final Trained Model
#         │
#         ▼
# Predict Customer Churn
#         │
#         ▼
# Estimate Churn Probability
#         │
#         ▼
# Display Risk Level
#         │
#         ▼
# Provide Business Recommendation

# %% [markdown]
# # Application Features
#
# The deployed application provides the following capabilities:
#
# Interactive customer information form.
# Automatic feature engineering consistent with the training pipeline.
# Real-time customer churn prediction.
# Churn probability estimation.
# Customer risk categorization.
# Personalized business recommendations.
# Customer profile summary before prediction.
#
# The application automatically generates all engineered features, ensuring consistency between the deployment pipeline and the model training process.

# %% [markdown]
# # Tech Stack
#
# | Component            | Technology               |
# | -------------------- | ------------------------ |
# | Programming Language | Python                   |
# | Web Framework        | Streamlit                |
# | Machine Learning     | Scikit-learn             |
# | Model Serialization  | Joblib                   |
# | Data Processing      | Pandas                   |
# | Feature Engineering  | Custom utility functions |

# %% [markdown]
# # Project Structure
#
# CustomerRetentionAI/
#
# │
# ├── app/
# │   ├── app.py
# │   └── utils.py
# │
# ├── data/
# │   ├── raw/
# │   └── processed/
# │
# ├── models/
# │   └── final_model.pkl
# │
# ├── notebooks/
# │   ├── 01_EDA.ipynb
# │   ├── ...
# │   └── 13_Streamlit_Deployment.ipynb
# │
# ├── src/
# │
# ├── requirements.txt
# │
# ├── README.md
# │
# └── .gitignore

# %% [markdown]
# # Streamlit Application
#
# ![image.png](attachment:image.png)
#
# Application Home Page
#
# Project title
# Customer input form
# Sidebar
#
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# Customer Profile
#
# Entered customer information
# Generated customer profile
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-5.png](attachment:image-5.png)
#
# Prediction Results
#
# Churn probability
# Risk level
# Business recommendation

# %% [markdown]
# # Business Value
#
# The deployed application bridges the gap between machine learning experimentation and real-world business implementation.
#
# Rather than requiring technical expertise to generate predictions, the application allows customer service teams to assess customer churn risk instantly by entering customer information through a graphical interface.
#
# The predicted churn probability enables organizations to prioritize high-risk customers, while the business recommendations assist decision-makers in selecting appropriate customer retention strategies.
#
# By automating both prediction and feature engineering, the application ensures that the deployed system remains consistent with the machine learning pipeline developed during model training.

# %% [markdown]
# # Future Improvements
#
# Potential enhancements for future versions of the application include:
#
# Integration with live customer databases.
# Cloud deployment using Streamlit Community Cloud or AWS.
# REST API integration for enterprise systems.
# SHAP explanations for individual customer predictions.
# Customer authentication and user management.
# Dashboard for monitoring churn trends.
# Batch prediction using uploaded CSV files.
# Automated report generation.

# %% [markdown]
# # Summary
#
# Objective
#
# Deploy the final customer churn prediction model as an interactive Streamlit web application capable of generating real-time churn predictions and supporting customer retention decisions.
#
# Key Features
# Interactive customer input interface.
# Automatic feature engineering.
# Real-time churn prediction.
# Churn probability estimation.
# Customer risk categorization.
# Actionable business recommendations.
# Conclusion
#
# This notebook completes the end-to-end customer churn prediction project by deploying the final machine learning model as an interactive web application. The deployment demonstrates how predictive analytics can be integrated into business workflows, enabling customer service teams to identify high-risk customers and implement targeted retention strategies. By combining predictive modeling, feature engineering, explainability, business analysis, and deployment, the project provides a comprehensive example of an end-to-end machine learning solution that addresses both technical and business objectives.

# %%
streamlit run app/app.py
